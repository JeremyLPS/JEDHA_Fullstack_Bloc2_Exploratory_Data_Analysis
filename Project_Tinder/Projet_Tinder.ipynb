# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Exploration Dataframe

# %%
df = pd.read_csv('Speed_Dating_Data.csv', encoding='unicode_escape')
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
#Shape du Dataframe (8378 lignes/195 colonnes)
df.shape
# Out:
# (8378, 195)

# %%
#Infos du Dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Columns: 195 entries, iid to amb5_3
# dtypes: float64(174), int64(13), object(8)
# memory usage: 12.5+ MB

# %%
#Stats descriptives
df.describe()
# Out:
#                iid           id       gender          idg       condtn  \
# count  8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# mean    283.675937     8.960248     0.500597    17.327166     1.828837
# std     158.583367     5.491329     0.500029    10.940735     0.376673
# min       1.000000     1.000000     0.000000     1.000000     1.000000
# 25%     154.000000     4.000000     0.000000     8.000000     2.000000
# 50%     281.000000     8.000000     1.000000    16.000000     2.000000
# 75%     407.000000    13.000000     1.000000    26.000000     2.000000
# max     552.000000    22.000000     1.000000    44.000000     2.000000
#
#               wave        round     position     positin1        order  \
# count  8378.000000  8378.000000  8378.000000  6532.000000  8378.000000
# mean     11.350919    16.872046     9.042731     9.295775     8.927668
# std       5.995903     4.358458     5.514939     5.650199     5.477009
# ...

# %%
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %% [markdown]
# # DATA CLEANING

# %%
df2 = df.loc[:, ['match','int_corr']]

# %%
#Significativité des notes des deux partenaires avant le date et le match potentiel
sns.boxplot(data=df2, x='match',y='int_corr')
plt.title("Lien entre notes d'intérêts et les matchs ?",fontweight='bold');

# %% [markdown]
# ## Distribution équivalente et pas de différence notable de match selon que les partenaires aient les mêmes aspirations initiales ou pas.

# %%
df2.loc[(df2['int_corr'].abs()> 0.75) & (df['match'] == 'Yes') ,:].sort_values(by='int_corr',ascending=True)
# Out:
# Empty DataFrame
# Columns: [match, int_corr]
# Index: []

# %%
#Pourcentage de valeurs manquantes par colonne
pct_val_nul = round((df.isnull().sum()/len(df)*100),2).sort_values(ascending=False)
pct_val_nul
# Out:
# num_in_3    92.03
# numdat_3    82.14
# expnum      78.52
# sinc7_2     76.67
# amb7_2      76.67
# shar7_2     76.44
# attr7_2     76.32
# intel7_2    76.32
# fun7_2      76.32
# amb5_3      75.94
# attr7_3     75.94
# sinc7_3     75.94
# intel7_3    75.94
# fun7_3      75.94
# amb7_3      75.94
# shar7_3     75.94
# shar2_3     75.94
# attr5_3     75.94
# sinc5_3     75.94
# intel5_3    75.94
# fun5_3      75.94
# attr4_3     64.68
# sinc4_3     64.68
# intel4_3    64.68
# fun4_3      64.68
# amb4_3      64.68
# shar4_3     64.68
# attr2_3     64.68
# sinc2_3     64.68
# fun2_3      64.68
# intel2_3    64.68
# amb2_3      64.68
# mn_sat      62.60
# tuition     57.23
# you_call    52.57
# shar1_3     52.57
# date_3      52.57
# attr1_3     52.57
# sinc1_3     52.57
# intel1_3    52.57
# fun1_3      52.57
# amb1_3      52.57
# attr3_3     52.57
# sinc3_3     52.57
# intel3_3    52.57
# fun3_3      52.57
# amb3_3      52.57
# them_cal    52.57
# fun3_s      52.26
# intel3_s    52.26
# ...

# %%
#Nombre de colonnes qui ont +50% de valeurs manquantes
round(((pct_val_nul.values > 50).sum()/len(df.axes[1])*100),2)
# Out:
# 30.26

# %% [markdown]
# ## Beaucoup de colonnes (+ de 30%) avec + de 50% de valeurs manquantes

# %%
pct_val_nul.plot(
    figsize=(20, 15), kind='bar',
    title="Pourcentage de valeurs manquantes par feature",
    ylabel="% de valeurs manquantes")
plt.show()

# %%
#remplacement des valeurs numériques par des str
df['race']=df['race'].replace({1:"Black/African American",2:"European/Caucasian-American",3:"Latino/Hispanic American",
                               4:"Asian/Pacific Islander/Asian-American",5:"Native American",6:"Other"})

# %%
#remplacement des 0 et 1 par Female/Male pour la colonne gender
df['gender']=df['gender'].replace({0:"Female",1:"Male"})

# %%
#Pas de valeurs manquantes pour la feature 'match'
df['match'].isnull().any()
# Out:
# False

# %%
#remplacement des 0 et 1 par Yes/No pour la colonne match
df['match']=df['match'].replace({0:"No",1:"Yes"})

# %%
df['match'].value_counts(ascending=True)
# Out:
# Yes    1380
# No     6998
# Name: match, dtype: int64

# %%
#Pourcentage de matches
prct_match = df['match'].value_counts(normalize=True)*100
prct_match
# Out:
# No     83.528288
# Yes    16.471712
# Name: match, dtype: float64

# %%
#Déclaration des valeurs/légendes utilisées dans le Pie chart
labels = 'No Match', ' Match'
sizes = prct_match.values
explode = (0.1, 0)

#Déclaration fonction ax.pie
fig, ax = plt.subplots()
patches, texts, autotexts =ax.pie(sizes, labels=labels,autopct='%1.1f%%', colors = ['brown','green'], explode=explode, shadow=True)

#Boucle sur les éléments textes à passer en couleur blanc
for text in autotexts :
    text.set_color('white')

#Déclaration du titre et affichage du graphe
ax.set_title('Pourcentage de match',fontweight='bold')
plt.show()

# %% [markdown]
# ## Seulement 1 date sur 6 se conclut par un 'match'

# %%
#Creation de masques pour enlever les vagues 6 à 9 qui n'ont pas le même système de notation
waves = (df['wave'] < 6) | (df['wave'] > 9)
df_waves = df[waves]

# %%
# Création de masques pour chaque vague de speed dating
wave1= df['wave'] ==1
w1=df[wave1]

wave2 = df['wave']==2
w2 = df[wave2]

wave3 = df['wave']==3
w3 = df[wave3]

wave4 = df['wave']==4
w4 = df[wave4]

wave5 = df['wave']==5
w5 = df[wave5]

wave10 = df['wave']==10
w10 = df[wave10]

wave11 = df['wave']==11
w11 = df[wave11]

wave12 = df['wave']==12
w12 = df[wave12]

wave13 = df['wave']==13
w13 = df[wave13]

wave14 = df['wave']==14
w14 = df[wave14]

wave15 = df['wave']==15
w15 = df[wave15]

wave16 = df['wave']==16
w16 = df[wave16]

wave17 = df['wave']==17
w17 = df[wave17]

wave18 = df['wave']==18
w18 = df[wave18]

wave19 = df['wave']==19
w19 = df[wave19]

wave20 = df['wave']==20
w20 = df[wave20]

wave21 = df['wave']==21
w21 = df[wave21]

# %%
#Creation des masques pour différencier la population de femmes et celle des hommes
female = df_waves['gender']=='Female'
male = df_waves['gender']=='Male'

# %% [markdown]
# # Question 1 : "What are the least desirable attributes in a male partner? Does this differ for female partners?"

# %%
#Déclaration des attributs 
colonnes=['attr1_1','sinc1_1','intel1_1','fun1_1','amb1_1','shar1_1']

#Moyenne des notations par genre
df_waves.groupby('gender')[colonnes].mean().round(2)
# Out:
#         attr1_1  sinc1_1  intel1_1  fun1_1  amb1_1  shar1_1
# gender
# Female    18.79    18.38     21.57   17.04   12.01    12.26
# Male      29.11    16.23     19.56   17.66    7.50    10.26

# %% [markdown]
# ### Les hommes cherchent en moyenne davantage quelqu'un d'attractive que les femmes. Le critère "attractive" est une critère fondamental chez les hommes tandis que l'ambition arrive en dernière position.
# ### Pour les femmes, les points sont répartis de manière davantage homogène. Si l'ambition est aussi leur critère le moins important il l'est bien plus que pour les hommes. Aussi, le critère principal pour les femmes chez un homme est l'intelligence devant la beauté et la sincérité quasiment à égalité.

# %%
(df_waves.groupby('gender')[colonnes].mean()).plot.bar(width = 0.9,edgecolor = 'white',colormap='BrBG')
labels=['Attractive','Sincere','Intelligent','Fun','Ambitious','Shared interests']
plt.title('Moyenne des notes par attributs selon le genre',fontweight='bold')
plt.xticks(rotation=0)
plt.legend(labels=labels, bbox_to_anchor=(0.9, 0.5, 0.5, 0.5))
plt.ylabel('Moyenne de points sur 100',fontweight='bold')
plt.xlabel('Genre',fontweight='bold');

# %% [markdown]
# # Question 2 : "How important do people think attractiveness is in potential mate selection vs. its real impact?"

# %%
#Note moyenne donnée par les femmes pour l'attribut Attractiveness chez un homme
note_female_before = df_waves[female]['attr1_1'].mean().round(2)
note_female_before
# Out:
# 18.79

# %%
#Note moyenne donnée par les femmes pour l'attribut Attractiveness chez un homme après le speed dating
note_female_after = df_waves[female]['attr7_2'].mean().round(2)
note_female_after
# Out:
# 28.63

# %%
#Note moyenne donnée par les hommes pour l'attribut Attractiveness chez une femme avant le speed dating
note_male_before = df_waves[male]['attr1_1'].mean().round(2)
note_male_before
# Out:
# 29.11

# %%
#Note moyenne donnée par les hommes pour l'attribut Attractiveness chez une femme après le speed dating
note_male_after = df_waves[male]['attr7_2'].mean().round(2)
note_male_after
# Out:
# 37.31

# %%
#Delta entre note avant et note après speed dating
delta_femmes = round((note_female_after - note_female_before)/note_female_before*100,2)
delta_femmes
# Out:
# 52.37

# %%
#Delta entre note avant et note après speed dating
delta_hommes = round((note_male_after - note_male_before)/note_male_before*100,2)
delta_hommes
# Out:
# 28.17

# %% [markdown]
# ## Essayer la matrice de corrélation & tester les autres temporalités après le date

# %%
print("La note moyenne des femmes avant le speed dating concernant l'importance de l'attribut Attractiveness \n"
      "chez un homme était de :", note_female_before)
print("Après le speed dating cette note monte à :", note_female_after, "soit un impact réel", delta_femmes,"% supérieur")

print()

print("La note moyenne des hommes avant le speed dating concernant l'importance de l'attribut Attractiveness \n"
      "chez une femme était de :", note_male_before)
print("Après le speed dating cette note monte à :", note_male_after, "soit un impact réel", delta_hommes,"% supérieur")
# Out:
# La note moyenne des femmes avant le speed dating concernant l'importance de l'attribut Attractiveness
# chez un homme était de : 18.79
# Après le speed dating cette note monte à : 28.63 soit un impact réel 52.37 % supérieur
#
# La note moyenne des hommes avant le speed dating concernant l'importance de l'attribut Attractiveness
# chez une femme était de : 29.11
# Après le speed dating cette note monte à : 37.31 soit un impact réel 28.17 % supérieur

# %%
notes = pd.DataFrame({'Hommes' : [note_male_before,note_male_after], 
                      'Femmes' : [note_female_before,note_female_after]
                     },
                     index =['Notes avant speed dating','Notes après speed dating']
                        
                    )
notes
# Out:
#                           Hommes  Femmes
# Notes avant speed dating   29.11   18.79
# Notes après speed dating   37.31   28.63

# %%
#Plot du résultat de l'importance de l'attribut Attractiveness
notes.plot(kind='bar', colormap='coolwarm')
plt.ylabel('Note moyenne',fontweight='bold')
plt.xticks(rotation=0,fontweight='bold')
plt.title('Note moyenne de l\'attribut Attractiveness avant et après un speed dating',fontweight='bold');

# %% [markdown]
# ## ==> Que ce soit chez les hommes ou chez les femmes, le critère Attractiveness est finalement bien plus important qu'imaginé avant le speed dating

# %% [markdown]
# # Question 3 : "Are shared interests more important than a shared racial background?"

# %%
#Importance de la race dans un speed dating (en % de personnes par note)
round(df['imprace'].value_counts(normalize=True)*100,2)
# Out:
# 1.0     33.71
# 3.0     11.84
# 2.0     11.50
# 8.0      7.99
# 5.0      7.92
# 7.0      6.54
# 6.0      6.31
# 4.0      6.15
# 9.0      4.93
# 10.0     3.01
# 0.0      0.10
# Name: imprace, dtype: float64

# %% [markdown]
# ### ==> Importance de la même origine ethnique n'est pas un critère de sélection

# %%
df_waves['race'].value_counts()
# Out:
# European/Caucasian-American              3786
# Asian/Pacific Islander/Asian-American    1649
# Latino/Hispanic American                  569
# Other                                     446
# Black/African American                    308
# Name: race, dtype: int64

# %%
#remplacement des 0 et 1 par Yes/No pour la colonne samerace
df['samerace']=df['samerace'].replace({0:"No",1:"Yes"})

# %%
pd.crosstab(df['samerace'],df['match'])
# Out:
# match       No  Yes
# samerace
# No        4248  814
# Yes       2750  566

# %%
#Pourcentage de match selon samerace
round(df.groupby('samerace')['match'].value_counts(normalize=True)*100,2)
# Out:
# samerace  match
# No        No       83.92
#           Yes      16.08
# Yes       No       82.93
#           Yes      17.07
# Name: match, dtype: float64

# %% [markdown]
# ### ==> Mêmes proportions de match que le date soit entre personnes de même background ou pas

# %%
pd.crosstab(df['race'],df['match'], normalize=True)*100
# Out:
# match                                         No       Yes
# race
# Asian/Pacific Islander/Asian-American  20.625376  3.211064
# Black/African American                  4.028863  1.022249
# European/Caucasian-American            47.372219  9.476849
# Latino/Hispanic American                6.506314  1.479254
# Other                                   5.039086  1.238725

# %%
#Notes données après chaque date pour l'attribut "Shared_interests"
shared_interest = pd.crosstab(df['shar'].dropna(), df['match'])
shared_interest['%_yes'] = shared_interest['Yes']/shared_interest[['No','Yes']].sum(axis=1)*100

# %%
shared_interest[['No','Yes']].sum(axis=1)
# Out:
# shar
# 0.0       59
# 1.0      239
# 2.0      485
# 3.0      588
# 4.0      783
# 5.0     1465
# 5.5        1
# 6.0     1248
# 6.5        2
# 7.0     1150
# 7.5        4
# 8.0      771
# 8.5        2
# 9.0      317
# 10.0     197
# dtype: int64

# %%
shared_interest
# Out:
# match    No  Yes      %_yes
# shar
# 0.0      56    3   5.084746
# 1.0     233    6   2.510460
# 2.0     458   27   5.567010
# 3.0     557   31   5.272109
# 4.0     734   49   6.257982
# 5.0    1293  172  11.740614
# 5.5       1    0   0.000000
# 6.0    1017  231  18.509615
# 6.5       1    1  50.000000
# 7.0     852  298  25.913043
# 7.5       3    1  25.000000
# 8.0     529  242  31.387808
# 8.5       1    1  50.000000
# 9.0     207  110  34.700315
# 10.0    109   88  44.670051

# %%
# Creation de deux graphiques via plt.subplot()
plt.figure(figsize=(10,10))

# Creation countplot
plt.subplot(221)
sns.histplot(data=df_waves, x='shar', hue='match', palette= ['navy','mediumseagreen'], multiple='stack')
plt.ylabel('Nombre',color='midnightblue',fontweight='bold')
plt.xlabel('Note',color='midnightblue',fontweight='bold')
plt.title('Nombre de matches selon l\'importance \n de l\'attribut Shared_interest', color='midnightblue',fontweight='bold')

#Creation pointplot
plt.subplot(222)
sns.pointplot(data=shared_interest, y='%_yes', x=shared_interest.index.values, color='midnightblue')
plt.ylabel('% de match', color='midnightblue',fontweight='bold')
plt.xlabel('Note',color='midnightblue',fontweight='bold')
plt.title('Pourcentage de match selon la note donnée à l\'attribut \n Shared_interest',color='midnightblue',fontweight='bold')
plt.tight_layout()

plt.show()

# %% [markdown]
# ### ==> On peut voir que la proportion de match augmente à mesure que la note attribuée à la feature Shared_interests est élevée.
# ### Plus les intérêts communs sont nombreux plus la proportion de matches est importante (+30% de matches parmi les tous les dates qui ont attribués la note de 8 ou +)
# ### NB : Les notes à virgule (5.5, 6.5, 7.5 et 8.5), entre très petit nombre, "cassent" un peu la courbe globalement linéairement croissante.

# %% [markdown]
# # Question 4 : "Can people accurately predict their own perceived value in the dating market?"

# %%
#création du mask pour les colonnes correspondant au survey d'auto évaluation
colonnes_2=[col for col in df_waves.columns if '3_1' in col]
self_perception = df_waves[colonnes_2]

#Calcul de la moyenne de chaque attribut après suppression des valeurs manquantes
self_perception.dropna().mean()
# Out:
# attr3_1     7.004318
# sinc3_1     8.262805
# fun3_1      7.674658
# intel3_1    8.334127
# amb3_1      7.513848
# dtype: float64

# %%
#Colonnes des notes données par le partenaire
notes_partner = ['attr_o','sinc_o','intel_o','fun_o','amb_o']
rating_by_partner = df_waves[notes_partner]
rating_by_partner
# Out:
#       attr_o  sinc_o  intel_o  fun_o  amb_o
# 0        6.0     8.0      8.0    8.0    8.0
# 1        7.0     8.0     10.0    7.0    7.0
# 2       10.0    10.0     10.0   10.0   10.0
# 3        7.0     8.0      9.0    8.0    9.0
# 4        8.0     7.0      9.0    6.0    9.0
# ...      ...     ...      ...    ...    ...
# 8373    10.0     5.0      3.0    2.0    6.0
# 8374     6.0     3.0      7.0    3.0    7.0
# 8375     2.0     1.0      2.0    2.0    2.0
# 8376     5.0     7.0      5.0    5.0    3.0
# 8377     8.0     8.0      7.0    7.0    7.0
#
# [6816 rows x 5 columns]

# %%
#Concatenation des deux df (perception personnelle + perception du partenaire) et supression des lignes avec valeurs manquantes
self_perception_2 = pd.concat([self_perception,rating_by_partner], axis=1)
self_perception_2 = self_perception_2.dropna()
self_perception_2.mean()
# Out:
# attr3_1     7.003460
# sinc3_1     8.272862
# fun3_1      7.673093
# intel3_1    8.340583
# amb3_1      7.512935
# attr_o      6.133943
# sinc_o      7.127863
# intel_o     7.318174
# fun_o       6.356237
# amb_o       6.725902
# dtype: float64

# %%
#Réorganisation des index pour une meilleure visibilité des colonnes à comparer
self_perception_2.sort_index(axis=1, ascending=True)
self_perception_2[['diff_amb','diff_attr','diff_fun','diff_intel','diff_sinc']]=0

# %%
#Calcul de la différence entre les notes données par soi-même et par le partenaire pour chaque attribut
self_perception_2['diff_amb']= self_perception_2['amb_o']-self_perception_2['amb3_1']
self_perception_2['diff_attr'] = self_perception_2['attr_o']-self_perception_2['attr3_1']
self_perception_2['diff_fun'] = self_perception_2['fun_o']- self_perception_2['fun3_1']
self_perception_2['diff_intel'] = self_perception_2['intel_o']-self_perception_2['intel3_1']
self_perception_2['diff_sinc'] = self_perception_2['sinc_o']-self_perception_2['sinc3_1']

# %%
self_perception_2.mean()
# Out:
# attr3_1       7.003460
# sinc3_1       8.272862
# fun3_1        7.673093
# intel3_1      8.340583
# amb3_1        7.512935
# attr_o        6.133943
# sinc_o        7.127863
# intel_o       7.318174
# fun_o         6.356237
# amb_o         6.725902
# diff_amb     -0.787032
# diff_attr    -0.869517
# diff_fun     -1.316856
# diff_intel   -1.022409
# diff_sinc    -1.144999
# dtype: float64

# %%
#Différence moyenne entre la perception personnelle et la perception du partenaire
self_perception_2.iloc[:,-5:].abs().mean()
# Out:
# diff_amb      2.064673
# diff_attr     1.841803
# diff_fun      2.108914
# diff_intel    1.641457
# diff_sinc     2.006591
# dtype: float64

# %%
delta_amb = (((self_perception_2['amb_o'])-(self_perception_2['amb3_1']))/(self_perception_2['amb3_1'])*100).abs().mean().round(2)
delta_amb
# Out:
# 31.29

# %%
delta_attr = (((self_perception_2['diff_attr']))/(self_perception_2['attr3_1'])*100).abs().mean().round(2)
delta_attr
# Out:
# 27.45

# %%
delta_fun = (((self_perception_2['diff_fun']))/(self_perception_2['fun3_1'])*100).abs().mean().round(2)
delta_fun
# Out:
# 28.88

# %%
delta_intel = (((self_perception_2['diff_intel'])/(self_perception_2['intel3_1']))*100).abs().mean().round(2)
delta_intel
# Out:
# 19.65

# %%
delta_sinc = (((self_perception_2['diff_sinc']))/(self_perception_2['sinc3_1'])*100).abs().mean().round(2)
delta_sinc
# Out:
# 25.83

# %%
diff_notes = pd.DataFrame({"Attractive" : [self_perception_2['attr3_1'].mean(),self_perception_2['attr_o'].mean()],
              "Ambitious" : [self_perception_2['amb3_1'].mean(),self_perception_2['amb_o'].mean()],
              "Sincere" : [self_perception_2['sinc3_1'].mean(),self_perception_2['sinc_o'].mean()],
              "Fun" : [self_perception_2['fun3_1'].mean(),self_perception_2['fun_o'].mean()],
              "Intelligent" : [self_perception_2['intel3_1'].mean(),self_perception_2['intel_o'].mean()]
             },
                index =['Moyenne note auto-attribuée','Moyenne note donnée par partenaire']
            ).T
diff_notes
# Out:
#              Moyenne note auto-attribuée  Moyenne note donnée par partenaire
# Attractive                      7.003460                            6.133943
# Ambitious                       7.512935                            6.725902
# Sincere                         8.272862                            7.127863
# Fun                             7.673093                            6.356237
# Intelligent                     8.340583                            7.318174

# %% [markdown]
# # Essayer boxplot pour chaque attribut et chaque type d'evaluation

# %%
#Graphe de la différence de note moyenne pour chaque attributs entre perception personnelle et perception du partenaire rencontré
sns.lineplot(diff_notes, markers=True, markersize=10,palette=['navy','brown'])
plt.xlabel('Attributs',fontweight='bold')
plt.ylabel('Moyenne',fontweight='bold')
plt.title('Comparaison entre notes moyennes auto-attribuées et \n données par le partenaire rencontré',fontweight='bold')

plt.legend(bbox_to_anchor=(1, 0.5, 0.5, 0.5))
plt.show();

# %% [markdown]
# ### ==> En moyenne, les participants ont tendance à légèrement se surrévaluer par rapport à ce que pense le partenaire rencontré et ce pour chaque attribut
# ### De manière globale, les participants s'attribuent une note pour chaque attribut 1 point plus haut que ce que leur partenaire a lui noté.
# ### L'attribut "Fun" est la caractéristique la plus surrévaluée par les participants, l'ambition étant la moins surrévaluée.

# %% [markdown]
# # Question 5 : "In terms of getting a second date, is it better to be someone's first speed date of the night or their last?"

# %%
df_waves.groupby(['wave','order'])['match'].value_counts()
# Out:
# wave  order  match
# 1     1      No       14
#              Yes       6
#       2      No       14
#              Yes       6
#       3      No       14
#              Yes       6
#       4      No       14
#              Yes       6
#       5      No       10
#              Yes      10
#       6      No       14
#              Yes       6
#       7      No       14
#              Yes       6
#       8      No       16
#              Yes       4
#       9      No       14
#              Yes       6
#       10     No       14
#              Yes       6
# 2     1      No       29
#              Yes       6
#       2      No       34
#              Yes       1
#       3      No       28
#              Yes       7
#       4      No       26
#              Yes       9
#       5      No       29
#              Yes       6
#       6      No       31
#              Yes       4
#       7      No       31
#              Yes       4
#       8      No       35
#       9      No       34
# ...

# %%
# Creation de deux graphiques via plt.subplot()
plt.figure(figsize=(10,10))

# Creation barplot
plt.subplot(441)
sns.countplot(w1, x='order', hue='match')
plt.title('w1')
#Creation barplot
plt.subplot(442)
sns.countplot(w2, x='order', hue='match')
#Creation barplot
plt.subplot(443)
sns.countplot(w3, x='order', hue='match')
#Creation barplot
plt.subplot(444)
sns.countplot(w4, x='order', hue='match')
#Creation barplot
plt.subplot(445)
sns.countplot(w5, x='order', hue='match')
#Creation barplot
plt.subplot(446)
sns.countplot(w10, x='order', hue='match')
#Creation barplot
plt.subplot(447)
sns.countplot(w11, x='order', hue='match')
#Creation barplot
plt.subplot(448)
sns.countplot(w12, x='order', hue='match')
#Creation barplot
plt.subplot(449)
sns.countplot(w13, x='order', hue='match')
#Creation barplot
plt.subplot(4,4,10)
sns.countplot(w14, x='order', hue='match')
#Creation barplot
plt.subplot(4,4,11)
sns.countplot(w15, x='order', hue='match')
#Creation barplot
plt.subplot(4,4,12)
sns.countplot(w16, x='order', hue='match')
#Creation barplot
plt.subplot(4,4,13)
sns.countplot(w17, x='order', hue='match')
#Creation barplot
plt.subplot(4,4,14)
sns.countplot(w18, x='order', hue='match')
#Creation barplot
plt.subplot(4,4,15)
sns.countplot(w19, x='order', hue='match')
#Creation barplot
plt.subplot(4,4,16)
sns.countplot(w20, x='order', hue='match')


plt.tight_layout()

plt.show()

# %%
sns.countplot(w21, x='order', hue='match');

# %%
df_waves.loc[df_waves['wave']==1,:]
# Out:
#      iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0      1   1.0  Female    1       1     1     10         7       NaN      4
# 1      1   1.0  Female    1       1     1     10         7       NaN      3
# 2      1   1.0  Female    1       1     1     10         7       NaN     10
# 3      1   1.0  Female    1       1     1     10         7       NaN      5
# 4      1   1.0  Female    1       1     1     10         7       NaN      7
# 5      1   1.0  Female    1       1     1     10         7       NaN      6
# 6      1   1.0  Female    1       1     1     10         7       NaN      1
# 7      1   1.0  Female    1       1     1     10         7       NaN      2
# 8      1   1.0  Female    1       1     1     10         7       NaN      8
# 9      1   1.0  Female    1       1     1     10         7       NaN      9
# 10     2   2.0  Female    3       1     1     10         3       NaN     10
# ...

# %%
round(pd.crosstab(df_waves.groupby('waves')['order'],df_waves['match'], normalize='index')*100,2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 round(pd.crosstab(df_waves.groupby('waves')['order'],df_waves['match'], normalize='index')*100,2)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# ...

# %%
#Nombre de match selon le positionnement du date 
sns.countplot(data=w5, x='order', hue='match')
plt.title('Nombre de match selon le positionnement du date dans la soirée speed dating')
plt.ylabel('Nombre')
plt.xlabel('Ordre du date dans la soirée');

# %%
#Distribution des matches selon l'ordre du date
sns.kdeplot(x='order',data=w13,hue='match',fill=True)
plt.title('Distribution des matches selon l\'ordre du date')
plt.show()

# %%
df_waves['wave']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 8373    21
# 8374    21
# 8375    21
# 8376    21
# 8377    21
# Name: wave, Length: 6816, dtype: int64

# %%
w5.groupby('order').get_group(w5['order'].max())['match'].value_counts(normalize=True)*100
# Out:
# No     68.421053
# Yes    31.578947
# Name: match, dtype: float64

# %%
round((w4.groupby(['wave','order'])['match'].value_counts(normalize=True)*100),2)
# Out:
# wave  order  match
# 4     1      No       72.22
#              Yes      27.78
#       2      No       88.89
#              Yes      11.11
#       3      No       88.89
#              Yes      11.11
#       4      No       88.89
#              Yes      11.11
#       5      No       88.89
#              Yes      11.11
#       6      No       72.22
#              Yes      27.78
#       7      No       66.67
#              Yes      33.33
#       8      No       72.22
#              Yes      27.78
#       9      No       66.67
#              Yes      33.33
#       10     No       77.78
#              Yes      22.22
#       11     No       94.44
#              Yes       5.56
#       12     No       83.33
#              Yes      16.67
#       13     No       77.78
#              Yes      22.22
#       14     No       66.67
#              Yes      33.33
#       15     No       94.44
#              Yes       5.56
#       16     No       88.89
#              Yes      11.11
# ...

# %%
# Récupération des % de matches pour chaque dernier date pour chaque vague

liste = [w1,w2,w3,w4,w5]
j=1
for i in liste :
    print("Pour la VAGUE {}, le % de match au premier et au dernier rdv est (respectivement) de :".format(j))
    print(round((i.groupby('order').get_group(i['order'].min())['match']
                 .value_counts(normalize=True)*100),2).to_string()) #to_string pour enlever l'affichage de name 
                                                                    # et dtype dans les prints
    print()
    print(round((i.groupby('order').get_group(i['order'].max())['match']
                 .value_counts(normalize=True)*100),2).to_string()) #to_string pour enlever l'affichage de name 
                                                                    # et dtype dans les prints
    j=j+1
    print();

liste2 = [w10,w11,w12,w13,w14,w15,w16,w17,w18,w19,w20,w21]
a = 10
for k in liste2 :
    print("Pour la VAGUE {}, le % de match au premier et au dernier rdv est (respectivement) de :".format(a))
    print(round((k.groupby('order').get_group(k['order'].min())['match']
                 .value_counts(normalize=True)*100),2).to_string()) #to_string pour enlever l'affichage de name 
                                                                    # et dtype dans les prints
    print()
    print(round((k.groupby('order').get_group(k['order'].max())['match']
                 .value_counts(normalize=True)*100),2).to_string()) #to_string pour enlever l'affichage de name 
                                                                    # et dtype dans les prints
    a+=1
    print();
# Out:
# Pour la VAGUE 1, le % de match au premier et au dernier rdv est (respectivement) de :
# No     70.0
# Yes    30.0
#
# No     70.0
# Yes    30.0
#
# Pour la VAGUE 2, le % de match au premier et au dernier rdv est (respectivement) de :
# No     82.86
# Yes    17.14
#
# No     93.75
# Yes     6.25
#
# Pour la VAGUE 3, le % de match au premier et au dernier rdv est (respectivement) de :
# No     70.0
# Yes    30.0
#
# No     80.0
# Yes    20.0
#
# Pour la VAGUE 4, le % de match au premier et au dernier rdv est (respectivement) de :
# No     72.22
# Yes    27.78
#
# No     72.22
# Yes    27.78
#
# Pour la VAGUE 5, le % de match au premier et au dernier rdv est (respectivement) de :
# No     68.42
# Yes    31.58
#
# No     68.42
# Yes    31.58
#
# Pour la VAGUE 10, le % de match au premier et au dernier rdv est (respectivement) de :
# No    100.0
#
# No     77.78
# Yes    22.22
#
# Pour la VAGUE 11, le % de match au premier et au dernier rdv est (respectivement) de :
# No     71.43
# ...

# %%
#Pourcentage de match par vague et par position du date dans la soirée 
round((df_waves.groupby(['wave','order'])['match'].value_counts(normalize=True)*100),2)

# %%
def one_is_better(df,waves):
  df_a = df[df['wave']==waves]
  a=df_a[df_a["order"]==1][['match']].sum().values[0]/df_a[df_a["order"]==1][['match']].shape[0]
  b=df_a[df_a["order"]==df_a['round'].unique()[0]][['match']].sum().values[0]/df_a[df_a["order"]==df_a['round'].unique()[0]][['match']].shape[0]
  return a>b

# %%
meann=[]
for i in df['wave'].unique():
    meann.append(one_is_better(df,i))
print("le premier rendez vous à",np.mean(meann),"% d'etre meilleur que le dernier rendez vous")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 3
#       1 meann=[]
#       2 for i in df['wave'].unique():
# ----> 3     meann.append(one_is_better(df,i))
#       4 print("le premier rendez vous à",np.mean(meann),"% d'etre meilleur que le dernier rendez vous")
#
# Cell In[76], line 3, in one_is_better(df, waves)
#       1 def one_is_better(df,waves):
#       2   df_a = df[df['wave']==waves]
# ----> 3   a=df_a[df_a["order"]==1][['match']].sum().values[0]/df_a[df_a["order"]==1][['match']].shape[0]
#       4   b=df_a[df_a["order"]==df_a['round'].unique()[0]][['match']].sum().values[0]/df_a[df_a["order"]==df_a['round'].unique()[0]][['match']].shape[0]
#       5   return a>b
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
